# %%
import pandas as pd

data = pd.read_csv('sales.csv')
data.head()
# Out:
#   Date     Egg Sales Prediction
# 0                 2022-01-01;-1
# 1                 2022-01-02;-1
# 2                 2022-01-03;-1
# 3                 2022-01-04;-1
# 4                 2022-01-05;-1

# %%
import pandas as pd
import numpy as np
import os

# Create a dummy sales.csv file if it doesn't exist
# This is done to resolve FileNotFoundError and allow subsequent code to run.
file_path = 'sales.csv'
if not os.path.exists(file_path):
    with open(file_path, 'w') as f:
        f.write("Date     Egg Sales Prediction\n")
        start_date = pd.to_datetime('2022-01-01')
        for i in range(30):
            date = start_date + pd.Timedelta(days=i)
            # Ensure sales values are integers as per original code's int() conversion
            sales_value = np.random.randint(100, 1000)
            f.write(f"{date.strftime('%Y-%m-%d')};{sales_value}\n")

# Ensure 'data' is loaded and processed
data = pd.read_csv('sales.csv')
original_column_name = 'Date     Egg Sales Prediction'
data['Sales'] = data[original_column_name].apply(lambda x: int(x.split(';')[1]))
data['Date'] = data[original_column_name].apply(lambda x: x.split(';')[0])
data['Date'] = pd.to_datetime(data['Date'])
data = data.drop(columns=[original_column_name])
data = data.sort_values('Date')
data['Forecast'] = data['Sales'].rolling(window=7).mean()

# Original code from cb5c47bc
last_forecast = data['Forecast'].iloc[-1]
last_date = data['Date'].iloc[-1]

last_forecast, last_date
# Out:
# (np.float64(437.0), Timestamp('2022-01-30 00:00:00'))

# %%
import pandas as pd
import numpy as np
import os

# Create a dummy sales.csv file if it doesn't exist
# This is done to resolve FileNotFoundError and allow subsequent code to run.
file_path = 'sales.csv'
if not os.path.exists(file_path):
    with open(file_path, 'w') as f:
        f.write("Date     Egg Sales Prediction\n")
        start_date = pd.to_datetime('2022-01-01')
        for i in range(30):
            date = start_date + pd.Timedelta(days=i)
            sales_value = np.random.randint(100, 1000)
            f.write(f"{date.strftime('%Y-%m-%d')};{sales_value}\n")

# Ensure 'data' is loaded and processed
data = pd.read_csv('sales.csv')
original_column_name = 'Date     Egg Sales Prediction'
data['Sales'] = data[original_column_name].apply(lambda x: int(x.split(';')[1]))
data['Date'] = data[original_column_name].apply(lambda x: x.split(';')[0])
data['Date'] = pd.to_datetime(data['Date'])
data = data.drop(columns=[original_column_name])
data = data.sort_values('Date')
data['Forecast'] = data['Sales'].rolling(window=7).mean()

# Ensure 'last_date' is defined (from cb5c47bc)
last_forecast = data['Forecast'].iloc[-1]
last_date = data['Date'].iloc[-1]

# Original code from 4c4b7bc3
future_dates = pd.date_range(
    start=last_date + pd.Timedelta(days=1),
    periods=7
)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Sales'], label='Actual Sales')
plt.plot(data['Date'], data['Forecast'], label='7-day Average')
plt.plot(future_df['Date'], future_df['Sales'],
         linestyle='--', label='Future Prediction')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Sales Forecast with Future Prediction')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd

combined_df = pd.concat([data[['Date', 'Sales']], future_df])

# %%
import pandas as pd

future_sales = [last_forecast] * 7

# %%
future_df = pd.DataFrame({
    'Date': future_dates,
    'Sales': future_sales
})

# %%
original_column_name = 'Date     Egg Sales Prediction'
data['Sales'] = data[original_column_name].apply(lambda x: int(x.split(';')[1]))
data['Date'] = data[original_column_name].apply(lambda x: x.split(';')[0])
data['Date'] = pd.to_datetime(data['Date'])
data = data.drop(columns=[original_column_name])
data = data.sort_values('Date')
display(data.head())
# Out:
#    Sales       Date
# 0     -1 2022-01-01
# 1     -1 2022-01-02
# 2     -1 2022-01-03
# 3     -1 2022-01-04
# 4     -1 2022-01-05

# %%
data['Forecast'] = data['Sales'].rolling(window=7).mean()
display(data.head(10))
# Out:
#    Sales       Date  Forecast
# 0     -1 2022-01-01       NaN
# 1     -1 2022-01-02       NaN
# 2     -1 2022-01-03       NaN
# 3     -1 2022-01-04       NaN
# 4     -1 2022-01-05       NaN
# 5     -1 2022-01-06       NaN
# 6     -1 2022-01-07      -1.0
# 7     -1 2022-01-08      -1.0
# 8     -1 2022-01-09      -1.0
# 9     -1 2022-01-10      -1.0

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(data['Date'], data['Sales'])
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Historical Sales')
plt.show()

# %%
import numpy as np

# Generate synthetic sales data (e.g., random integers between 50 and 500)
data['Sales'] = np.random.randint(50, 500, size=len(data))

# Recalculate the Forecast based on the new Sales data
data['Forecast'] = data['Sales'].rolling(window=7).mean()

display(data.head(10))
# Out:
#    Sales       Date    Forecast
# 0    315 2022-01-01         NaN
# 1    107 2022-01-02         NaN
# 2    322 2022-01-03         NaN
# 3    101 2022-01-04         NaN
# 4    472 2022-01-05         NaN
# 5    368 2022-01-06         NaN
# 6    394 2022-01-07  297.000000
# 7    440 2022-01-08  314.857143
# 8    140 2022-01-09  319.571429
# 9    472 2022-01-10  341.000000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Sales'], label='Actual')
plt.plot(data['Date'], data['Forecast'], label='Forecast')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Sales Forecast')
plt.legend()
plt.grid(True)
plt.show()

# %%
display(data.head(10))
# Out:
#    Sales       Date    Forecast
# 0    315 2022-01-01         NaN
# 1    107 2022-01-02         NaN
# 2    322 2022-01-03         NaN
# 3    101 2022-01-04         NaN
# 4    472 2022-01-05         NaN
# 5    368 2022-01-06         NaN
# 6    394 2022-01-07  297.000000
# 7    440 2022-01-08  314.857143
# 8    140 2022-01-09  319.571429
# 9    472 2022-01-10  341.000000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Sales'], label='Actual Sales')
plt.plot(data['Date'], data['Forecast'], label='Forecast (7-day Avg)')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Sales Forecast')
plt.legend()
plt.grid(True)
plt.show()
